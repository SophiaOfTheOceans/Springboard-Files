# %% [markdown]
# # Forecasting

# %% [markdown]
# In the other notebooks, we were trying to do a classic regression problem, predicting revenue given a list of features such as temperature, fuel price, and CPI for a certain week. In this notebook, we're going to try making future predictions about the total revenue of Walmart given the past revenue alone.
#
# First we're going to import the necessary modules and load the dataset.210
# 35.476+

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\songs\Desktop\Springboard Files\Capstone 2\data\Raw\train.csv')
df.head()
# Out:
#    Store  Dept        Date  Weekly_Sales  IsHoliday  Temperature  Fuel_Price  \
# 0     26    92  2011-08-26      87235.57      False        61.10       3.796
# 1     34    22  2011-03-25       5945.97      False        53.11       3.480
# 2     21    28  2010-12-03       1219.89      False        50.43       2.708
# 3      8     9  2010-09-17      11972.71      False        75.32       2.582
# 4     19    55  2012-05-18       8271.82      False        58.81       4.029
#
#    MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5         CPI  \
# 0        NaN        NaN        NaN        NaN        NaN  136.213613
# 1        NaN        NaN        NaN        NaN        NaN  128.616064
# 2        NaN        NaN        NaN        NaN        NaN  211.265543
# 3        NaN        NaN        NaN        NaN        NaN  214.878556
# 4   12613.98        NaN       11.5    1705.28    3600.79  138.106581
#
#    Unemployment Type    Size
# 0         7.767    A  152513
# ...

# %%
df['Date'] = df['Date'].astype('datetime64')
df_time = df.groupby('Date').sum()['Weekly_Sales']
df_time.head()
# Out:
# Date
# 2010-02-05    32412189.61
# 2010-02-12    33135624.24
# 2010-02-19    32731216.57
# 2010-02-26    29765485.51
# 2010-03-05    30540210.29
# Name: Weekly_Sales, dtype: float64

# %%
plt.figure(figsize=(20,10))
plt.plot(df_time)
